# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
diabetes = pd.read_csv(r'C:\Users\karthikp\Downloads\Inceptors\Preprocessing files\diabetes.csv')
diabetes
# Out:
#      Number of times pregnant   Plasma glucose concentration  \
# 0                           6                            148
# 1                           1                             85
# 2                           8                            183
# 3                           1                             89
# 4                           0                            137
# ..                        ...                            ...
# 763                        10                            101
# 764                         2                            122
# 765                         5                            121
# 766                         1                            126
# 767                         1                             93
#
#       Diastolic blood pressure   Triceps skin fold thickness  \
# 0                           72                            35
# 1                           66                            29
# ...

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes[:9]
# Out:
#    Number of times pregnant   Plasma glucose concentration  \
# 0                         6                            148
# 1                         1                             85
# 2                         8                            183
# 3                         1                             89
# 4                         0                            137
# 5                         5                            116
# 6                         3                             78
# 7                        10                            115
# 8                         2                            197
#
#     Diastolic blood pressure   Triceps skin fold thickness  \
# 0                         72                            35
# 1                         66                            29
# 2                         64                             0
# 3                         66                            23
# 4                         40                            35
# ...

# %%
diabetes.columns
# Out:
# Index(['Number of times pregnant', ' Plasma glucose concentration',
#        ' Diastolic blood pressure', ' Triceps skin fold thickness',
#        ' 2-Hour serum insulin', ' Body mass index',
#        ' Diabetes pedigree function', ' Age (years)', ' Class variable'],
#       dtype='object')

# %%
x = diabetes.drop(' Class variable',1)
# Out:
# C:\Users\karthikp\AppData\Local\Temp/ipykernel_12836/696826134.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x = diabetes.drop(' Class variable',1)

# %%
x[:4]
# Out:
#    Number of times pregnant   Plasma glucose concentration  \
# 0                         6                            148
# 1                         1                             85
# 2                         8                            183
# 3                         1                             89
#
#     Diastolic blood pressure   Triceps skin fold thickness  \
# 0                         72                            35
# 1                         66                            29
# 2                         64                             0
# 3                         66                            23
#
#     2-Hour serum insulin   Body mass index   Diabetes pedigree function  \
# 0                      0              33.6                        0.627
# 1                      0              26.6                        0.351
# 2                      0              23.3                        0.672
# 3                     94              28.1                        0.167
#
# ...

# %%
y = diabetes.iloc[:, -1]
y[:4]
# Out:
# 0    YES
# 1     NO
# 2    YES
# 3     NO
# Name:  Class variable, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 4)

# %%
x_train
# Out:
#      Number of times pregnant   Plasma glucose concentration  \
# 596                         0                             67
# 90                          1                             80
# 734                         2                            105
# 694                         2                             90
# 517                         7                            125
# ..                        ...                            ...
# 360                         5                            189
# 709                         2                             93
# 439                         6                            107
# 174                         2                             75
# 122                         2                            107
#
#       Diastolic blood pressure   Triceps skin fold thickness  \
# 596                         76                             0
# 90                          55                             0
# ...

# %%
x_test
# Out:
#      Number of times pregnant   Plasma glucose concentration  \
# 390                         1                            100
# 146                         9                             57
# 136                         0                            100
# 420                         1                            119
# 328                         2                            102
# ..                        ...                            ...
# 374                         2                            122
# 288                         4                             96
# 282                         7                            133
# 754                         8                            154
# 363                         4                            146
#
#       Diastolic blood pressure   Triceps skin fold thickness  \
# 390                         66                            29
# 146                         80                            37
# ...

# %%
y_train
# Out:
# 596     NO
# 90      NO
# 734     NO
# 694     NO
# 517     NO
#       ...
# 360    YES
# 709    YES
# 439     NO
# 174     NO
# 122     NO
# Name:  Class variable, Length: 614, dtype: object

# %%
y_test
# Out:
# 390     NO
# 146     NO
# 136     NO
# 420     NO
# 328    YES
#       ...
# 374     NO
# 288     NO
# 282     NO
# 754    YES
# 363    YES
# Name:  Class variable, Length: 154, dtype: object

# %%
model = GaussianNB()

# %%
model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %%
acc_score = accuracy_score(y_test, y_pred)

# %%
print(acc_score)

# %%
confusion_matrix (y_test, y_pred)

# %% [raw]
# print(classification_report(y_test,y_pred))

# %%
x1 = diabetes.drop(' Class variable',1)
# Out:
# C:\Users\karthikp\AppData\Local\Temp/ipykernel_13212/106208760.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x1 = diabetes.drop(' Class variable',1)

# %%
x1[:5]
# Out:
#    Number of times pregnant   Plasma glucose concentration  \
# 0                         6                            148
# 1                         1                             85
# 2                         8                            183
# 3                         1                             89
# 4                         0                            137
#
#     Diastolic blood pressure   Triceps skin fold thickness  \
# 0                         72                            35
# 1                         66                            29
# 2                         64                             0
# 3                         66                            23
# 4                         40                            35
#
#     2-Hour serum insulin   Body mass index   Diabetes pedigree function  \
# 0                      0              33.6                        0.627
# 1                      0              26.6                        0.351
# ...

# %%
y1 = diabetes.iloc[:,-1]
y1
# Out:
# 0      YES
# 1       NO
# 2      YES
# 3       NO
# 4      YES
#       ...
# 763     NO
# 764     NO
# 765     NO
# 766    YES
# 767     NO
# Name:  Class variable, Length: 768, dtype: object

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1,y1,test_size=0.2,random_state=5)

# %%
model=GaussianNB()

# %%
model.fit(x1_train,y1_train)
# Out:
# GaussianNB()

# %%
y1_pred = model.predict(x1_test)

# %%
acc_score1 = accuracy_score(y1_test,y1_pred)

# %%
print(acc_score1)
# Out:
# 0.7662337662337663

# %%
confusion_matrix(y1_test,y1_pred)
# Out:
# array([[84, 16],
#        [20, 34]], dtype=int64)

# %%
print(classification_report(y1_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.81      0.84      0.82       100
#          YES       0.68      0.63      0.65        54
#
#     accuracy                           0.77       154
#    macro avg       0.74      0.73      0.74       154
# weighted avg       0.76      0.77      0.76       154
