# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
os.chdir(r'C:\Users\karthikp\Downloads\Inceptors\Preprocessing files')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\karthikp\\Downloads\\Inceptors\\Preprocessing files'

# %%
df = pd.read_csv('Adult2.csv')
df
# Out:
#          age         workclass  fnlwgt     education education_num  \
# 0         39         State-gov   77516     Bachelors            13
# 1         50  Self-emp-not-inc   83311     Bachelors            13
# 2         38           Private  215646       HS-grad             9
# 3         53           Private  234721          11th             7
# 4         28           Private  338409     Bachelors            13
# ...      ...               ...     ...           ...           ...
# 4995      43           Private  222971       5th-6th             3
# 4996      31           Private  259425       HS-grad             9
# 4997      47      Self-emp-inc  212120       HS-grad             9
# 4998  #NAME?           Private  245880       HS-grad             9
# 4999      58         Local-gov   54947  Some-college            10
#
#           marital_status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df2=pd.read_csv('auto.csv')
df2
# Out:
#      Unnamed: 0  symboling  normalized_losses         make fuel_type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#     aspiration num_doors   body_style drive_wheels engine_location  ...  \
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\karthikp\\Downloads\\Inceptors\\Preprocessing files'

# %%
df2 = pd.read_csv('Adult2.csv',na_values=['#NAME?'])

# %%
df2.tail()
# Out:
#        age     workclass    fnlwgt     education  education_num  \
# 4995  43.0       Private  222971.0       5th-6th            3.0
# 4996  31.0       Private  259425.0       HS-grad            9.0
# 4997  47.0  Self-emp-inc  212120.0       HS-grad            9.0
# 4998   NaN       Private  245880.0       HS-grad            9.0
# 4999  58.0     Local-gov   54947.0  Some-college           10.0
#
#           marital_status         occupation   relationship   race     sex  \
# 4995       Never-married  Machine-op-inspct      Unmarried  White  Female
# 4996  Married-civ-spouse       Craft-repair        Husband  White    Male
# 4997  Married-civ-spouse       Craft-repair        Husband  White    Male
# 4998       Never-married       Adm-clerical  Not-in-family  White    Male
# 4999       Never-married     Prof-specialty  Not-in-family  White  Female
#
#       capital_gain  capital_loss  hours_per_week native_country income
# ...

# %%
df2[:10]
# Out:
#     age         workclass    fnlwgt  education  education_num  \
# 0  39.0         State-gov   77516.0  Bachelors           13.0
# 1  50.0  Self-emp-not-inc   83311.0  Bachelors           13.0
# 2  38.0           Private  215646.0    HS-grad            9.0
# 3  53.0           Private  234721.0       11th            7.0
# 4  28.0           Private  338409.0  Bachelors           13.0
# 5  37.0           Private  284582.0    Masters           14.0
# 6  49.0           Private  160187.0        9th            5.0
# 7  52.0  Self-emp-not-inc  209642.0    HS-grad            9.0
# 8  31.0           Private   45781.0    Masters           14.0
# 9  42.0           Private  159449.0  Bachelors           13.0
#
#           marital_status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
df2.shape
# Out:
# (5000, 15)

# %%
df2['income'].value_counts()
# Out:
# <=50K    3779
# >50K     1221
# Name: income, dtype: int64

# %%
df2['sex'].value_counts()
# Out:
# Male      3332
# Female    1621
# Name: sex, dtype: int64

# %%
df2['workclass'].value_counts()
# Out:
# Private             3435
# Self-emp-not-inc     383
# ?                    331
# Local-gov            329
# State-gov            193
# Self-emp-inc         182
# Federal-gov          146
# Without-pay            1
# Name: workclass, dtype: int64

# %%
df2.dtypes
# Out:
# age               float64
# workclass          object
# fnlwgt            float64
# education          object
# education_num     float64
# marital_status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital_gain        int64
# capital_loss        int64
# hours_per_week      int64
# native_country     object
# income             object
# dtype: object

# %%
dict2={'age':[39,50,38,53,28],'workclass':['State-gov','Self-emp-not-inc','Private','Private','Private'],
             'fnlwgt':[77516,83311,215646,234721,338409],
'education':['Bachelors','Bachelors','Hs-grad','11th','Bachelors'],
'education_num':[13,13,'nine',7,13],
'marital_status':['Never-married','Married-civ-spouse','Divorced','Married-civ-spouse','Married-civ-spouse']}
df3=pd.DataFrame(dict2)
df3
# Out:
#    age         workclass  fnlwgt  education education_num      marital_status
# 0   39         State-gov   77516  Bachelors            13       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors            13  Married-civ-spouse
# 2   38           Private  215646    Hs-grad          nine            Divorced
# 3   53           Private  234721       11th             7  Married-civ-spouse
# 4   28           Private  338409  Bachelors            13  Married-civ-spouse

# %%
df3.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num     object
# marital_status    object
# dtype: object

# %%
#df2['income']=[0 if x == '<=50K' else 1 for x in df2['income']]
df2['income']=[0 if x == '<=50K' else 1 for x in df2['income']]

# %%
df2[4990:]
# Out:
#        age         workclass    fnlwgt     education  education_num  \
# 4990  33.0  Self-emp-not-inc  118267.0    Assoc-acdm           12.0
# 4991  29.0           Private  266043.0           9th            5.0
# 4992  23.0           Private   35633.0       HS-grad            9.0
# 4993  23.0           Private   74568.0  Some-college           10.0
# 4994  39.0           Private  214816.0     Bachelors           13.0
# 4995  43.0           Private  222971.0       5th-6th            3.0
# 4996  31.0           Private  259425.0       HS-grad            9.0
# 4997  47.0      Self-emp-inc  212120.0       HS-grad            9.0
# 4998   NaN           Private  245880.0       HS-grad            9.0
# 4999  58.0         Local-gov   54947.0  Some-college           10.0
#
#           marital_status         occupation   relationship   race     sex  \
# 4990            Divorced              Sales  Not-in-family  White    Male
# ...

# %%
obj_col = df2.select_dtypes(include=['object'])

# %%
obj_col
# Out:
#              workclass     education      marital_status         occupation  \
# 0            State-gov     Bachelors       Never-married       Adm-clerical
# 1     Self-emp-not-inc     Bachelors  Married-civ-spouse    Exec-managerial
# 2              Private       HS-grad            Divorced  Handlers-cleaners
# 3              Private          11th  Married-civ-spouse  Handlers-cleaners
# 4              Private     Bachelors  Married-civ-spouse     Prof-specialty
# ...                ...           ...                 ...                ...
# 4995           Private       5th-6th       Never-married  Machine-op-inspct
# 4996           Private       HS-grad  Married-civ-spouse       Craft-repair
# 4997      Self-emp-inc       HS-grad  Married-civ-spouse       Craft-repair
# 4998           Private       HS-grad       Never-married       Adm-clerical
# 4999         Local-gov  Some-college       Never-married     Prof-specialty
#
#        relationship   race     sex native_country
# ...

# %%
obj_col[obj_col.isnull().any(axis=1)]
# Out:
#         workclass     education      marital_status         occupation  \
# 3         Private          11th  Married-civ-spouse  Handlers-cleaners
# 33    Federal-gov  Some-college  Married-civ-spouse       Adm-clerical
# 81        Private             ?  Married-civ-spouse      Other-service
# 88        Private           9th       Never-married              Sales
# 110       Private     Bachelors       Never-married              Sales
# ...           ...           ...                 ...                ...
# 4842      Private       HS-grad           Separated              Sales
# 4868      Private  Some-college       Never-married              Sales
# 4910      Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 4931      Private       HS-grad       Never-married      Other-service
# 4982            ?  Some-college       Never-married                  ?
#
#         relationship   race     sex native_country
# 3            Husband  Black     NaN  United-States
# ...

# %%
obj_col['num_doors'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'num_doors'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
obj_col = obj_col.fillna({'num_doors':'four'})
obj_col[obj_col.isnull().any(axis=1)]

# %%
obj_col['body_style'].value_counts()

# %%
obj_col['drive_wheels'].value_counts()

# %%
pd.get_dummies(obj_col, columns=['body_style','drive_wheels'], prefix=['body','drive']).head()

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
lb_style = LabelBinarizer()

# %%
lb_result = lb_style.fit_transform(obj_col['body_style'])
pd.DataFrame(lb_result,columns=lb_style.classes_).tail()

# %%
lb_result

# %%
lb_style.classes_

# %%
obj_col['num_cylinders'].value_counts()

# %%
obj_col['num_doors'].value_counts()

# %%
dict1={'num_cylinders':{'four':[4],'six':[6],'five':[5],'eight':[8],'two':[2],
                       'three':[3],'twelve':[12]},
      'num_doors':{'four':4,'two':2}}

# %%
obj_col.replace(dict1, inplace=True)

# %%
obj_col['num_cylinders'].value_counts()

# %%
obj_col.dtypes

# %%
obj_col[:3]

# %%
obj_col['make'].value_counts()

# %%
obj_col['make'].value_counts().head()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb_make = LabelEncoder()

# %%
obj_col['make_code']=lb_make.fit_transform(obj_col['make'])

# %%
obj_col[['make','make_code']].head(10)

# %%
obj_col['make'].unique()

# %%
obj_col['make_code'].unique()

# %%
obj_col[:4]

# %%
obj_col['engine_type'].value_counts()

# %%
obj_col['engine_type'].nunique()

# %%
var1 = range(5)
for i in var1:
    for j in range(i+1):
        print('* ',end="")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
var2 = range(6)
num=1
for i in var2:
    for j in range(num, i+1):
        print(i,end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
var2 = range(6)
num=1
for i in var2:
    for j in range(num, i+1):
        print(j,end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
var3 = int(input('Enter a numer:'))
for i in range(var3):
    for j in range (0, i+1):
        print("* ",end= " ")
    print()

for i in range(var3,0,-1):
    for j in range (0, i-1):
        print("* ", end=" ")
    print()
# Out:
# Enter a numer:5
# *
# *  *
# *  *  *
# *  *  *  *
# *  *  *  *  *
# *  *  *  *
# *  *  *
# *  *
# *

# %%
var4 = int(input("Enter a number for max. no. rows"))

for i in range(var4):
    for j in range (0, i+1):
        print("* ",end=" ")
    print()
    
for i in range(var4+1,0,-1):
    for j in range (0, i-1):
        print('* ', end=" ")
    print()
# Out:
# Enter a number for max. no. rows5
# *
# *  *
# *  *  *
# *  *  *  *
# *  *  *  *  *
# *  *  *  *  *
# *  *  *  *
# *  *  *
# *  *
# *
